# %% [markdown]
# # TF Sign Language Identifier Model
# ## (by Youssef Hussein Ahmed)
#
# ### Contact with me:
# [<img align="left" width="35px" style= "padding-right: 10px" src="https://cdn.jsdelivr.net/npm/simple-icons@v3/icons/linkedin.svg" />][linkedin]
# [<img align="left" width="35px" style= "padding-right: 10px" src="https://cdn.jsdelivr.net/npm/simple-icons@v3/icons/upwork.svg" />][upwork]
# [<img align="left" width="35px" style= "padding-right: 10px" src="https://cdn.jsdelivr.net/npm/simple-icons@v3/icons/github.svg" />][github]
# [<img align="left" width="35px" style= "padding-right: 10px" src="https://cdn.jsdelivr.net/npm/simple-icons@v3/icons/facebook.svg" />][facebook]
#
# [linkedin]: https://www.linkedin.com/in/just-youssef
# [upwork]: https://www.upwork.com/freelancers/~01bf41aeaec6f293c5
# [github]: https://github.com/just-youssef
# [facebook]: https://www.facebook.com/just.johnny99

# %% [markdown]
# ## Table of Contents
#
# - [1 - Packages](#1)
# - [2 - Load the SIGNS Dataset](#2)
#     - [2.1 - Split the Data into Train/Valid Sets](#2-1)
# - [3 - signsModel](#3)
#     - [3.1 - Building the Model](#3-1)
#     - [3.2 - Compiling the Model](#3-2)
# - [4 - Training the signsModel](#4)

# %% [markdown]
# <a name='1'></a>
# ## 1 - Packages

# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import scipy
from PIL import Image
import pandas as pd
import tensorflow as tf
import tensorflow.keras.layers as tfl
from tensorflow.python.framework import ops
from cnn_utils import *

# %matplotlib inline

# %% [markdown]
# <a name='2'></a>
# ## 2 - Load the SIGNS Dataset
#
# As a reminder, the SIGNS dataset is a collection of 6 signs representing numbers from 0 to 5.

# %%
# Loading the data (signs)
X_train_orig, Y_train_orig, X_val_orig, Y_val_orig, classes = load_signs_dataset()

# %% [markdown]
# <img src="SIGNS.png" style="width:800px;height:300px;">
#
# The next cell will show you an example of a labelled image in the dataset. Feel free to change the value of `index` below and re-run to see different examples.

# %%
# Example of an image from the dataset
index = 9
plt.imshow(X_train_orig[index])
print ("y = " + str(np.squeeze(Y_train_orig[:, index])))
# Out:
# y = 4

# %% [markdown]
# <a name='2-1'></a>
# ## 2.1 - Split the Data into Train/Val Sets

# %%
X_train = X_train_orig/255.
X_val = X_val_orig/255.
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_val = convert_to_one_hot(Y_val_orig, 6).T
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_val.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_val shape: " + str(X_val.shape))
print ("Y_val shape: " + str(Y_val.shape))
# Out:
# number of training examples = 1080
# number of test examples = 120
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_val shape: (120, 64, 64, 3)
# Y_val shape: (120, 6)

# %% [markdown]
# <a name='3'></a>
# ## 2- signsModel
#
# Implementing the `signModel` function below to build the following model: `CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE`.

# %% [markdown]
# <a name='2-1'></a>
# ### 3.1 - Building the Model

# %%
def signsModel(input_shape=(64, 64, 3)):
    """
    Implements the forward propagation for the model:
    CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
    Note that for simplicity and grading purposes, you'll hard-code some values
    such as the stride and kernel (filter) sizes. 
    Normally, functions should take these values as function parameters.
    
    Arguments:
    input_img -- input dataset, of shape (input_shape)

    Returns:
    model -- TF Keras model (object containing the information for the entire training process) 
    """    
    # Input: shape = input_shape
    inputs = tf.keras.Input(shape=input_shape)
    
    ## CONV2D: 8 filters 4x4, stride of 1, padding 'SAME'
    Z1 = tf.keras.layers.Conv2D(filters=8, kernel_size=(4,4), strides=(1, 1), padding='same')(inputs)
    
    ## RELU
    A1 = tf.keras.layers.ReLU()(Z1)
    
    ## MAXPOOL: window 8x8, stride 8, padding 'SAME'
    P1 = tf.keras.layers.MaxPool2D(pool_size=(8, 8), strides=(8,8), padding='same')(A1)
    
    ## CONV2D: 16 filters 2x2, stride 1, padding 'SAME'
    Z2 = tf.keras.layers.Conv2D(filters=16, kernel_size=(2,2), strides=(1, 1), padding='same')(P1)
    
    ## RELU
    A2 = tf.keras.layers.ReLU()(Z2)
    
    ## MAXPOOL: window 4x4, stride 4, padding 'SAME'
    P2 = tf.keras.layers.MaxPool2D(pool_size=(4, 4), strides=(4,4), padding='same')(A2)
    
    ## FLATTEN
    F = tf.keras.layers.Flatten()(P2)
    
    ## Dense layer
    ## 6 neurons in output layer. Hint: one of the arguments should be "activation='softmax'" 
    outputs = tf.keras.layers.Dense(units=6, activation='softmax')(F)
        
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    return model

# %% [markdown]
# <a name='3-2'></a>
# ### 3.2 - Compile the Model

# %%
model = signsModel()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d (Conv2D)             (None, 64, 64, 8)         392
#
#  re_lu (ReLU)                (None, 64, 64, 8)         0
#
#  max_pooling2d (MaxPooling2D  (None, 8, 8, 8)          0
#  )
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 16)          528
#
#  re_lu_1 (ReLU)              (None, 8, 8, 16)          0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 16)         0
#  2D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 6)                 390
#
# =================================================================
# Total params: 1,310
# Trainable params: 1,310
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# <a name='4'></a>
# ## 4 - Train the signsModel

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, Y_train)).batch(32)
val_ds = tf.data.Dataset.from_tensor_slices((X_val, Y_val)).batch(32)
history = model.fit(train_ds, epochs=200, validation_data=val_ds)
# Out:
# Epoch 1/200
# 34/34 [==============================] - 3s 63ms/step - loss: 1.8018 - accuracy: 0.1759 - val_loss: 1.7874 - val_accuracy: 0.1333
# Epoch 2/200
# 34/34 [==============================] - 2s 55ms/step - loss: 1.7850 - accuracy: 0.1935 - val_loss: 1.7822 - val_accuracy: 0.2000
# Epoch 3/200
# 34/34 [==============================] - 2s 53ms/step - loss: 1.7789 - accuracy: 0.2324 - val_loss: 1.7783 - val_accuracy: 0.1917
# Epoch 4/200
# 34/34 [==============================] - 2s 52ms/step - loss: 1.7727 - accuracy: 0.2509 - val_loss: 1.7718 - val_accuracy: 0.2250
# Epoch 5/200
# 34/34 [==============================] - 2s 53ms/step - loss: 1.7639 - accuracy: 0.2861 - val_loss: 1.7632 - val_accuracy: 0.2750
# Epoch 6/200
# 34/34 [==============================] - 2s 55ms/step - loss: 1.7513 - accuracy: 0.3083 - val_loss: 1.7527 - val_accuracy: 0.2917
# Epoch 7/200
# 34/34 [==============================] - 2s 57ms/step - loss: 1.7332 - accuracy: 0.3287 - val_loss: 1.7375 - val_accuracy: 0.2917
# Epoch 8/200
# 34/34 [==============================] - 2s 52ms/step - loss: 1.7055 - accuracy: 0.3509 - val_loss: 1.7184 - val_accuracy: 0.3250
# Epoch 9/200
# 34/34 [==============================] - 2s 53ms/step - loss: 1.6653 - accuracy: 0.3769 - val_loss: 1.6879 - val_accuracy: 0.3333
# Epoch 10/200
# 34/34 [==============================] - 2s 55ms/step - loss: 1.6096 - accuracy: 0.4222 - val_loss: 1.6303 - val_accuracy: 0.3750
# Epoch 11/200
# 34/34 [==============================] - 2s 53ms/step - loss: 1.5414 - accuracy: 0.4676 - val_loss: 1.5678 - val_accuracy: 0.4333
# Epoch 12/200
# 34/34 [==============================] - 2s 57ms/step - loss: 1.4654 - accuracy: 0.4972 - val_loss: 1.4981 - val_accuracy: 0.4667
# Epoch 13/200
# 34/34 [==============================] - 2s 57ms/step - loss: 1.3865 - accuracy: 0.5324 - val_loss: 1.4265 - val_accuracy: 0.4750
# Epoch 14/200
# 34/34 [==============================] - 2s 54ms/step - loss: 1.3055 - accuracy: 0.5667 - val_loss: 1.3556 - val_accuracy: 0.5500
# Epoch 15/200
# 34/34 [==============================] - 2s 58ms/step - loss: 1.2262 - accuracy: 0.5935 - val_loss: 1.2852 - val_accuracy: 0.5583
# Epoch 16/200
# 34/34 [==============================] - 2s 53ms/step - loss: 1.1511 - accuracy: 0.6269 - val_loss: 1.2151 - val_accuracy: 0.5833
# Epoch 17/200
# 34/34 [==============================] - 2s 53ms/step - loss: 1.0827 - accuracy: 0.6537 - val_loss: 1.1531 - val_accuracy: 0.5833
# Epoch 18/200
# 34/34 [==============================] - 2s 54ms/step - loss: 1.0207 - accuracy: 0.6657 - val_loss: 1.0968 - val_accuracy: 0.6000
# Epoch 19/200
# 34/34 [==============================] - 2s 61ms/step - loss: 0
200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.1387 - accuracy: 0.9630 - val_loss: 0.3423 - val_accuracy: 0.8667
# Epoch 118/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.1367 - accuracy: 0.9620 - val_loss: 0.3406 - val_accuracy: 0.8750
# Epoch 119/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.1351 - accuracy: 0.9630 - val_loss: 0.3387 - val_accuracy: 0.8750
# Epoch 120/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.1332 - accuracy: 0.9639 - val_loss: 0.3393 - val_accuracy: 0.8750
# Epoch 121/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.1313 - accuracy: 0.9648 - val_loss: 0.3377 - val_accuracy: 0.8750
# Epoch 122/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.1296 - accuracy: 0.9667 - val_loss: 0.3355 - val_accuracy: 0.8750
# Epoch 123/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.1276 - accuracy: 0.9667 - val_loss: 0.3358 - val_accuracy: 0.8750
# Epoch 124/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.1262 - accuracy: 0.9685 - val_loss: 0.3359 - val_accuracy: 0.8750
# Epoch 125/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.1246 - accuracy: 0.9685 - val_loss: 0.3334 - val_accuracy: 0.8750
# Epoch 126/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.1230 - accuracy: 0.9694 - val_loss: 0.3344 - val_accuracy: 0.8750
# Epoch 127/200
# 34/34 [==============================] - 2s 58ms/step - loss: 0.1213 - accuracy: 0.9722 - val_loss: 0.3334 - val_accuracy: 0.8750
# Epoch 128/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.1197 - accuracy: 0.9722 - val_loss: 0.3338 - val_accuracy: 0.8750
# Epoch 129/200
# 34/34 [==============================] - 2s 57ms/step - loss: 0.1180 - accuracy: 0.9722 - val_loss: 0.3337 - val_accuracy: 0.8750
# Epoch 130/200
# 34/34 [==============================] - 2s 57ms/step - loss: 0.1166 - accuracy: 0.9722 - val_loss: 0.3316 - val_accuracy: 0.8750
# Epoch 131/200
# 34/34 [==============================] - 2s 57ms/step - loss: 0.1148 - accuracy: 0.9722 - val_loss: 0.3323 - val_accuracy: 0.8833
# Epoch 132/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.1133 - accuracy: 0.9731 - val_loss: 0.3330 - val_accuracy: 0.8833
# Epoch 133/200
# 34/34 [==============================] - 2s 58ms/step - loss: 0.1120 - accuracy: 0.9741 - val_loss: 0.3314 - val_accuracy: 0.8833
# Epoch 134/200
# 34/34 [==============================] - 2s 57ms/step - loss: 0.1104 - accuracy: 0.9741 - val_loss: 0.3317 - val_accuracy: 0.8833
# Epoch 135/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.1090 - accuracy: 0.9741 - val_loss: 0.3312 - val_accuracy: 0.8833
# Epoch 136/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.1075 - accuracy: 0.9741 - val_loss: 0.3314 - val_accuracy: 0.8833
# Epoch 137/200
# 34/34 [==============================] - 2s 58ms/step - loss: 0.1063 - accuracy: 0.9741 - val_loss: 0.3305 - val_accuracy: 0.8833
# Epoch 138/200
# 34/34 [==============================] - 2s 58ms/step - loss: 0.1048 - accuracy: 0.9750 - val_loss: 0.3313 - val_accuracy: 0.8833
# Epoch 139/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.1036 - accuracy: 0.9750 - val_loss: 0.3313 - val_accuracy: 0.8833
# Epoch 140/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.1022 - accuracy: 0.9759 - val_loss: 0.3308 - val_accuracy: 0.8833
# Epoch 141/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.1009 - accuracy: 0.9769 - val_loss: 0.3316 - val_accuracy: 0.8833
# Epoch 142/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0997 - accuracy: 0.9778 - val_loss: 0.3306 - val_accuracy: 0.8833
# Epoch 143/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0984 - accuracy: 0.9778 - val_loss: 0.3308 - val_accuracy: 0.8833
# Epoch 144/200
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0973 - accuracy: 0.9787 - val_loss: 0.3314 - val_accuracy: 0.8833
# Epoch 145/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0959 - accuracy: 0.9787 - val_loss: 0.3315 - val_accuracy: 0.8917
# Epoch 146/200
# 34/34 [==============================] - 2s 58ms/step - loss: 0.0947 - accuracy: 0.9787 - val_loss: 0.3317 - val_accuracy: 0.8833
# Epoch 147/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0933 - accuracy: 0.9796 - val_loss: 0.3310 - val_accuracy: 0.8917
# Epoch 148/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0921 - accuracy: 0.9796 - val_loss: 0.3314 - val_accuracy: 0.8917
# Epoch 149/200
# 34/34 [==============================] - 2s 58ms/step - loss: 0.0907 - accuracy: 0.9796 - val_loss: 0.3328 - val_accuracy: 0.8917
# Epoch 150/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0896 - accuracy: 0.9806 - val_loss: 0.3326 - val_accuracy: 0.8917
# Epoch 151/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0884 - accuracy: 0.9806 - val_loss: 0.3334 - val_accuracy: 0.8917
# Epoch 152/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0874 - accuracy: 0.9815 - val_loss: 0.3333 - val_accuracy: 0.8917
# Epoch 153/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0860 - accuracy: 0.9833 - val_loss: 0.3342 - val_accuracy: 0.8917
# Epoch 154/200
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0849 - accuracy: 0.9843 - val_loss: 0.3360 - val_accuracy: 0.8917
# Epoch 155/200
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0837 - accuracy: 0.9852 - val_loss: 0.3362 - val_accuracy: 0.8917
# Epoch 156/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0828 - accuracy: 0.9852 - val_loss: 0.3357 - val_accuracy: 0.8917
# Epoch 157/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0816 - accuracy: 0.9861 - val_loss: 0.3358 - val_accuracy: 0.8917
# Epoch 158/200
# 34/34 [==============================] - 2s 67ms/step - loss: 0.0806 - accuracy: 0.9861 - val_loss: 0.3375 - val_accuracy: 0.8917
# Epoch 159/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0797 - accuracy: 0.9861 - val_loss: 0.3374 - val_accuracy: 0.8917
# Epoch 160/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0785 - accuracy: 0.9861 - val_loss: 0.3387 - val_accuracy: 0.8917
# Epoch 161/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0775 - accuracy: 0.9880 - val_loss: 0.3381 - val_accuracy: 0.8917
# Epoch 162/200
# 34/34 [==============================] - 2s 70ms/step - loss: 0.0766 - accuracy: 0.9880 - val_loss: 0.3391 - val_accuracy: 0.8917
# Epoch 163/200
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0755 - accuracy: 0.9880 - val_loss: 0.3402 - val_accuracy: 0.8917
# Epoch 164/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0746 - accuracy: 0.9880 - val_loss: 0.3409 - val_accuracy: 0.8917
# Epoch 165/200
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0737 - accuracy: 0.9889 - val_loss: 0.3414 - val_accuracy: 0.8917
# Epoch 166/200
# 34/34 [==============================] - 2s 58ms/step - loss: 0.0731 - accuracy: 0.9889 - val_loss: 0.3422 - val_accuracy: 0.8917
# Epoch 167/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0720 - accuracy: 0.9889 - val_loss: 0.3408 - val_accuracy: 0.8917
# Epoch 168/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0711 - accuracy: 0.9889 - val_loss: 0.3423 - val_accuracy: 0.8917
# Epoch 169/200
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0703 - accuracy: 0.9907 - val_loss: 0.3420 - val_accuracy: 0.8917
# Epoch 170/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0694 - accuracy: 0.9898 - val_loss: 0.3438 - val_accuracy: 0.8917
# Epoch 171/200
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0686 - accuracy: 0.9907 - val_loss: 0.3444 - val_accuracy: 0.8917
# Epoch 172/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0677 - accuracy: 0.9907 - val_loss: 0.3444 - val_accuracy: 0.8917
# Epoch 173/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0669 - accuracy: 0.9907 - val_loss: 0.3445 - val_accuracy: 0.8917
# Epoch 174/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0665 - accuracy: 0.9907 - val_loss: 0.3450 - val_accuracy: 0.8917
# Epoch 175/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0655 - accuracy: 0.9917 - val_loss: 0.3449 - val_accuracy: 0.8917
# Epoch 176/200
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0648 - accuracy: 0.9917 - val_loss: 0.3439 - val_accuracy: 0.8917
# Epoch 177/200
# 34/34 [==============================] - 2s 58ms/step - loss: 0.0639 - accuracy: 0.9917 - val_loss: 0.3455 - val_accuracy: 0.8917
# Epoch 178/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0634 - accuracy: 0.9917 - val_loss: 0.3477 - val_accuracy: 0.8917
# Epoch 179/200
# 34/34 [==============================] - 2s 58ms/step - loss: 0.0625 - accuracy: 0.9917 - val_loss: 0.3456 - val_accuracy: 0.8917
# Epoch 180/200
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0618 - accuracy: 0.9917 - val_loss: 0.3470 - val_accuracy: 0.8917
# Epoch 181/200
# 34/34 [==============================] - 2s 58ms/step - loss: 0.0609 - accuracy: 0.9917 - val_loss: 0.3468 - val_accuracy: 0.8917
# Epoch 182/200
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0605 - accuracy: 0.9935 - val_loss: 0.3481 - val_accuracy: 0.8917
# Epoch 183/200
# 34/34 [==============================] - 3s 76ms/step - loss: 0.0596 - accuracy: 0.9935 - val_loss: 0.3478 - val_accuracy: 0.8917
# Epoch 184/200
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0592 - accuracy: 0.9935 - val_loss: 0.3499 - val_accuracy: 0.8917
# Epoch 185/200
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0585 - accuracy: 0.9935 - val_loss: 0.3497 - val_accuracy: 0.8917
# Epoch 186/200
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0579 - accuracy: 0.9935 - val_loss: 0.3486 - val_accuracy: 0.8917
# Epoch 187/200
# 34/34 [==============================] - 2s 50ms/step - loss: 0.0573 - accuracy: 0.9944 - val_loss: 0.3512 - val_accuracy: 0.8917
# Epoch 188/200
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0567 - accuracy: 0.9944 - val_loss: 0.3504 - val_accuracy: 0.8917
# Epoch 189/200
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0560 - accuracy: 0.9944 - val_loss: 0.3511 - val_accuracy: 0.8917
# Epoch 190/200
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0553 - accuracy: 0.9963 - val_loss: 0.3513 - val_accuracy: 0.8917
# Epoch 191/200
# 34/34 [==============================] - 2s 57ms/step - loss: 0.0550 - accuracy: 0.9963 - val_loss: 0.3544 - val_accuracy: 0.8917
# Epoch 192/200
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0541 - accuracy: 0.9963 - val_loss: 0.3524 - val_accuracy: 0.8917
# Epoch 193/200
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0536 - accuracy: 0.9972 - val_loss: 0.3542 - val_accuracy: 0.8917
# Epoch 194/200
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0531 - accuracy: 0.9963 - val_loss: 0.3527 - val_accuracy: 0.8917
# Epoch 195/200
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0521 - accuracy: 0.9972 - val_loss: 0.3521 - val_accuracy: 0.8917
# Epoch 196/200
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0519 - accuracy: 0.9972 - val_loss: 0.3532 - val_accuracy: 0.8917
# Epoch 197/200
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0512 - accuracy: 0.9972 - val_loss: 0.3545 - val_accuracy: 0.8917
# Epoch 198/200
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0507 - accuracy: 0.9981 - val_loss: 0.3546 - val_accuracy: 0.8917
# Epoch 199/200
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0500 - accuracy: 0.9981 - val_loss: 0.3557 - val_accuracy: 0.8917
# Epoch 200/200
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0492 - accuracy: 0.9972 - val_loss: 0.3535 - val_accuracy: 0.8917

# %%
# Plot the training and validation accuracy
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
